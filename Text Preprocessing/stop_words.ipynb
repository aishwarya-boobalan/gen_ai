When the group finally reached the top, Meera was amazed by the view. She could see the coastline, the blue water, distant villages, and several small boats moving across the sea. The wind was stronger at the top of the hill, and clouds were slowly moving across the sky. Meera sat quietly for a while and wrote a few thoughts in her notebook.

During the following days, she continued exploring different parts of the town. She visited a small museum, attended a traditional music performance, and tried several local dishes. One evening, she joined a cooking class where a local family taught visitors how to prepare traditional food using fresh vegetables, coconut, spices, and herbs.

Meera enjoyed listening to the stories shared by the family. They explained that recipes were often passed from parents to children and that certain dishes were prepared only during special festivals. She realized that food was more than something people ate every day. It was connected to family memories, traditions, celebrations, and local history.

In the evenings, the town became quieter. Small restaurants began serving food, music could be heard from nearby streets, and families gathered outside their homes. Meera often returned to the beach and watched the sunset. The sky changed from blue to orange, pink, and purple before slowly becoming dark.

One evening, she spoke with a young fisherman who was repairing his nets near the shore. He told her that his work could be difficult because the weather was not always predictable. Storms could appear suddenly, and some days the boats returned with very little fish. However, he said that he loved the sea and could not imagine living far away from it.

Meera found his words interesting. In her own life, she had often complained about her busy schedule and small problems. Listening to him reminded her that every person faced different challenges and that people often learned to adapt to the circumstances around them.

Before returning home, Meera bought a few handmade gifts for her family and friends. She also took one final walk along the beach. The place that had felt unfamiliar when she first arrived now seemed familiar and meaningful. She remembered the people she had met, the stories she had heard, and the peaceful moments she had spent near the sea.

When she returned to her city, her daily responsibilities were still waiting for her. The streets were still crowded, and life quickly became busy again. However, Meera felt different. The journey had reminded her that she did not always need to wait for a perfect moment to experience something new.

She understood that traveling was not only about visiting famous places or taking photographs. It was also about listening carefully, learning from people, understanding different cultures, and noticing the small details of everyday life. Sometimes, leaving a familiar place for a short period could help a person return with a clearer mind and a new perspective.

The memories of the coastal town remained with Meera for a long time. Whenever life became stressful, she remembered the sound of the waves, the smell of the sea, and the quiet evenings near the beach. She promised herself that she would continue exploring new places whenever she had the opportunity, because every journey had the potential to teach her something that she could not learn by staying in the same place.
'''

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aishw\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
#sentence tokenization
from nltk.tokenize import sent_tokenize
sentence=sent_tokenize(corpus)
print(sentence)
# Out:
# ['\nDuring the winter holidays, Meera decided to travel to a coastal town that she had heard about from her grandparents many years earlier.', 'The town was located far from the crowded streets, busy markets, and tall buildings of the city where she lived.', 'For several months, she had been feeling tired because her daily routine was filled with work, responsibilities, and long hours spent indoors.', 'She wanted to spend some time in a peaceful place where she could walk slowly, enjoy the sea, meet new people, and experience a different way of life.', 'The journey began early in the morning.', 'Meera packed a small suitcase with clothes, a notebook, a camera, a water bottle, and a few books.', 'Her mother prepared some food for the train journey and reminded her to be careful.', 'After saying goodbye to her family, Meera arrived at the railway station before sunrise.', 'The station was already crowded with passengers carrying bags and waiting for trains.', 'Some people were drinking
# ...

# %%
from nltk.tokenize import word_tokenize
stemmer=PorterStemmer()

# %%
#removing stop words and applying stemming
for i in range(len(sentence)):
    words=word_tokenize(sentence[i])
    words=[stemmer.stem(word) for word in words if word not in stopwords.words('english')]
    words=' '.join(words)
    print(words)
# Out:
# dure winter holiday , meera decid travel coastal town heard grandpar mani year earlier .
# the town locat far crowd street , busi market , tall build citi live .
# for sever month , feel tire daili routin fill work , respons , long hour spent indoor .
# she want spend time peac place could walk slowli , enjoy sea , meet new peopl , experi differ way life .
# the journey began earli morn .
# meera pack small suitcas cloth , notebook , camera , water bottl , book .
# her mother prepar food train journey remind care .
# after say goodby famili , meera arriv railway station sunris .
# the station alreadi crowd passeng carri bag wait train .
# some peopl drink tea , other read newspap speak phone .
# when train final arriv , meera found seat near window .
# as journey began , citi slowli disappear behind .
# the build becam fewer , road becam quieter , open field appear side railway track .
# she watch farmer work distanc children walk toward school .
# ...

# %% [markdown]
# the words are not accurate so trying eith snowball stemmer

# %%
from nltk.stem import SnowballStemmer
snowball_stem=SnowballStemmer('english')

# %%
for i in range(len(sentence)):
    words=word_tokenize(sentence[i])
    words=[snowball_stem.stem(word) for word in words if word not in stopwords.words('english')]
    words=' '.join(words)
    print(words)
# Out:
# dure winter holiday , meera decid travel coastal town heard grandpar mani year earlier .
# the town locat far crowd street , busi market , tall build citi live .
# for sever month , feel tire daili routin fill work , respons , long hour spent indoor .
# she want spend time peac place could walk slowli , enjoy sea , meet new peopl , experi differ way life .
# the journey began earli morn .
# meera pack small suitcas cloth , notebook , camera , water bottl , book .
# her mother prepar food train journey remind care .
# after say goodby famili , meera arriv railway station sunris .
# the station alreadi crowd passeng carri bag wait train .
# some peopl drink tea , other read newspap speak phone .
# when train final arriv , meera found seat near window .
# as journey began , citi slowli disappear behind .
# the build becam fewer , road becam quieter , open field appear side railway track .
# she watch farmer work distanc children walk toward school .
# ...

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aishw\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
wordnet=WordNetLemmatizer()
for i in range(len(sentence)):
    words=word_tokenize(sentence[i])
    words=[wordnet.lemmatize(word.lower(),pos='v') for word in words if word not in stopwords.words('english')]
    words=' '.join(words)
    print(words)
# Out:
# during winter holiday , meera decide travel coastal town hear grandparents many years earlier .
# the town locate far crowd streets , busy market , tall buildings city live .
# for several months , feel tire daily routine fill work , responsibilities , long hours spend indoors .
# she want spend time peaceful place could walk slowly , enjoy sea , meet new people , experience different way life .
# the journey begin early morning .
# meera pack small suitcase clothe , notebook , camera , water bottle , book .
# her mother prepare food train journey remind careful .
# after say goodbye family , meera arrive railway station sunrise .
# the station already crowd passengers carry bag wait train .
# some people drink tea , others read newspapers speak phone .
# when train finally arrive , meera find seat near window .
# as journey begin , city slowly disappear behind .
# the buildings become fewer , roads become quieter , open field appear side railway track .
# ...
