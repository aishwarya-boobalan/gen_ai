# %%
pip install nltk

# %%
corpus="""This is my first sentence. \n
This is my second sentence. 
This is my third sentence. 
This is my fourth sentence. 
This is my fifth sentence. This is my sixth sentence. 
This is my seventh sentence. This is my eighth sentence. 
This is my ninth sentence. This is my tenth sentence.
"""
print(corpus)
# Out:
# This is my first sentence.
#
# This is my second sentence.
# This is my third sentence.
# This is my fourth sentence.
# This is my fifth sentence. This is my sixth sentence.
# This is my seventh sentence. This is my eighth sentence.
# This is my ninth sentence. This is my tenth sentence.

# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aishw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
#sentence tokenization
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['This is my first sentence.',
#  'This is my second sentence.',
#  'This is my third sentence.',
#  'This is my fourth sentence.',
#  'This is my fifth sentence.',
#  'This is my sixth sentence.',
#  'This is my seventh sentence.',
#  'This is my eighth sentence.',
#  'This is my ninth sentence.',
#  'This is my tenth sentence.']

# %%
document=sent_tokenize(corpus)
for sent in document:
    print(sent)
    
#each sent is an element in the list where document is a list,and each element is a sentence in the list.
# Out:
# This is my first sentence.
# This is my second sentence.
# This is my third sentence.
# This is my fourth sentence.
# This is my fifth sentence.
# This is my sixth sentence.
# This is my seventh sentence.
# This is my eighth sentence.
# This is my ninth sentence.
# This is my tenth sentence.

# %%
from nltk.tokenize import  word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['This',
#  'is',
#  'my',
#  'first',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'second',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'third',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'fourth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'fifth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'sixth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'seventh',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'eighth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'ninth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'tenth',
#  'sentence',
#  '.']

# %%
for sent in document:
    print(word_tokenize(sent))
# Out:
# ['This', 'is', 'my', 'first', 'sentence', '.']
# ['This', 'is', 'my', 'second', 'sentence', '.']
# ['This', 'is', 'my', 'third', 'sentence', '.']
# ['This', 'is', 'my', 'fourth', 'sentence', '.']
# ['This', 'is', 'my', 'fifth', 'sentence', '.']
# ['This', 'is', 'my', 'sixth', 'sentence', '.']
# ['This', 'is', 'my', 'seventh', 'sentence', '.']
# ['This', 'is', 'my', 'eighth', 'sentence', '.']
# ['This', 'is', 'my', 'ninth', 'sentence', '.']
# ['This', 'is', 'my', 'tenth', 'sentence', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['This',
#  'is',
#  'my',
#  'first',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'second',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'third',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'fourth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'fifth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'sixth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'seventh',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'eighth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'ninth',
#  'sentence',
#  '.',
#  'This',
#  'is',
#  'my',
#  'tenth',
#  'sentence',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['This',
#  'is',
#  'my',
#  'first',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'second',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'third',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'fourth',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'fifth',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'sixth',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'seventh',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'eighth',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'ninth',
#  'sentence.',
#  'This',
#  'is',
#  'my',
#  'tenth',
#  'sentence',
#  '.']
